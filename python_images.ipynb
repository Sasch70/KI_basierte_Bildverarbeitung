# %% [markdown]
# # Python Images
# Operationen für Bilder in Python.

# %% [markdown]
# ### Matplotlib
# Bilder einladen und anzeigen.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.subplot(121) # nrows,ncols,index
img = mpimg.imread('data/greenscreen.jpg') #Format (1944,1555,3)
plt.imshow(img)

plt.subplot(122)
back = mpimg.imread('data/background.jpg')
plt.imshow(back)

print(img.shape)
# Out:
# (1944, 1555, 3)

# %%
# Bilder spiegeln
plt.imshow(np.flip(img,axis=0))

# oder mit flipud
plt.imshow(np.flipud(img))

# %%
plt.subplot(121) 
plt.imshow(np.rot90(img))

plt.subplot(122) 
plt.imshow(np.rot90(img,k=3)) #k: Anzahl Drehungen

# %% [markdown]
# ## PILLOW: Python Image Library

# %%
from PIL import Image

# Bild öffnen, img ist ein numpy array 
img = Image.open("data/cat.jpg")
print(type(img))
# Konvertierung in NumPy-Array
img_data = np.asarray( img, dtype="int32" )

plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Home\Git\KI_basierte_Bildverarbeitung\python_images.ipynb Zelle 7 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Home/Git/KI_basierte_Bildverarbeitung/python_images.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from PIL import Image
#       <a href='vscode-notebook-cell:/c%3A/Home/Git/KI_basierte_Bildverarbeitung/python_images.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> # Bild öffnen, img ist ein numpy array
# ----> <a href='vscode-notebook-cell:/c%3A/Home/Git/KI_basierte_Bildverarbeitung/python_images.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> img = Image.open("cat.jpg")
#       <a href='vscode-notebook-cell:/c%3A/Home/Git/KI_basierte_Bildverarbeitung/python_images.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> print(type(img))
# ...
